# %% [markdown]
# Читаем наш датасет с помощью библиотеки pandas

# %%
import pandas as pd
import matplotlib.pyplot as plt
import missingno as msno
import seaborn as sns
import numpy as np

# Загружаем данные из pandas
df = pd.read_csv('valid_filtred3.csv')
df.head(10)
# Out:
#    target   col476   col480     col484   col488     col492   col496   col500  \
# 0       0      NaN      NaN        NaN      NaN        NaN      NaN      NaN
# 1       0  59.8983  59.5791  59.738701  59.5791  59.579102  30.2618  30.1154
# 2       0      NaN      NaN        NaN      NaN        NaN      NaN      NaN
# 3       0      NaN      NaN        NaN      NaN        NaN      NaN      NaN
# 4       0      NaN      NaN        NaN      NaN        NaN      NaN      NaN
# 5       0      NaN      NaN        NaN      NaN        NaN      NaN      NaN
# 6       0  55.7386  55.7386  55.738602  55.7386  55.738602  37.6068  37.6068
# 7       0  55.7483  45.0355  47.713699  45.0355  45.035500  38.9750  37.6171
# 8       0      NaN      NaN        NaN      NaN        NaN      NaN      NaN
# 9       0  55.7386  55.7386  55.738602  55.7386  55.738602  37.6068  37.6068
#
#       col504   col508  ...     col2651     col2652     col2653     col2654  \
# 0        NaN      NaN  ...         NaN         NaN         NaN   4941670.0
# 1  30.188601  30.1154  ...  11789500.0  11789500.0  11789500.0  11789500.0
# 2        NaN      NaN  ...         NaN         NaN         NaN   7000000.0
# 3        NaN      NaN  ...         NaN         NaN         NaN         NaN
# 4        NaN      NaN  ...         NaN         NaN         NaN         NaN
# 5        NaN      NaN  ...         NaN         NaN         NaN         NaN
# 6  37.606800  37.6068  ...   7106000.0   7106000.0   7106000.0   7106000.0
# 7  38.635524  38.9750  ...         NaN         NaN         NaN         NaN
# 8        NaN      NaN  ...         NaN         NaN         NaN         NaN
# 9  37.606800  37.6068  ...   7014370.0   7014370.0   7014370.0   7014370.0
#
#       col2655     col2656     col2660     col2661     col2662   col2663
# 0   4941670.0   4941670.0   4941670.0   4941670.0   4941670.0  0.256919
# 1  11789500.0  11789500.0  11789500.0  11789500.0  11789500.0  0.267221
# 2   7000000.0   7000000.0   7000000.0   7000000.0   7000000.0  0.257217
# 3         NaN         NaN         NaN         NaN         NaN  0.256261
# 4         NaN         NaN  10391000.0  10391000.0  10391000.0  0.257348
# 5         NaN         NaN   8436000.0   8436000.0   8436000.0  0.256718
# 6   7106000.0   7106000.0   7106000.0   7106000.0   7106000.0  0.266021
# 7         NaN         NaN         NaN         NaN         NaN  0.263619
# 8         NaN         NaN         NaN         NaN         NaN  0.256261
# 9   7014370.0   7014370.0   7014370.0   7014370.0   7014370.0  0.264464
#
# [10 rows x 700 columns]

# %%
df.info()

df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3642 entries, 0 to 3641
# Columns: 700 entries, target to col2663
# dtypes: float64(698), int64(2)
# memory usage: 19.5 MB
#    target   col476   col480     col484   col488     col492   col496   col500  \
# 0       0      NaN      NaN        NaN      NaN        NaN      NaN      NaN
# 1       0  59.8983  59.5791  59.738701  59.5791  59.579102  30.2618  30.1154
# 2       0      NaN      NaN        NaN      NaN        NaN      NaN      NaN
# 3       0      NaN      NaN        NaN      NaN        NaN      NaN      NaN
# 4       0      NaN      NaN        NaN      NaN        NaN      NaN      NaN
#
#       col504   col508  ...     col2651     col2652     col2653     col2654  \
# 0        NaN      NaN  ...         NaN         NaN         NaN   4941670.0
# 1  30.188601  30.1154  ...  11789500.0  11789500.0  11789500.0  11789500.0
# 2        NaN      NaN  ...         NaN         NaN         NaN   7000000.0
# 3        NaN      NaN  ...         NaN         NaN         NaN         NaN
# 4        NaN      NaN  ...         NaN         NaN         NaN         NaN
#
#       col2655     col2656     col2660     col2661     col2662   col2663
# 0   4941670.0   4941670.0   4941670.0   4941670.0   4941670.0  0.256919
# 1  11789500.0  11789500.0  11789500.0  11789500.0  11789500.0  0.267221
# 2   7000000.0   7000000.0   7000000.0   7000000.0   7000000.0  0.257217
# 3         NaN         NaN         NaN         NaN         NaN  0.256261
# 4         NaN         NaN  10391000.0  10391000.0  10391000.0  0.257348
#
# [5 rows x 700 columns]

# %%
df.isnull().sum()
# Out:
# target        0
# col476     2821
# col480     2821
# col484     2821
# col488     2821
#            ...
# col2656    2604
# col2660    1280
# col2661    1280
# col2662    1280
# col2663       0
# Length: 700, dtype: int64

# %%
print("Размер данных после удаления:", df.shape)
# Out:
# Размер данных после удаления: (3642, 700)

# %%
missing_percentage = df.isnull().mean() * 100

print("Процент пропусков в каждой колонке:")
print(missing_percentage)
# Out:
# Процент пропусков в каждой колонке:
# target      0.000000
# col476     77.457441
# col480     77.457441
# col484     77.457441
# col488     77.457441
#              ...
# col2656    71.499176
# col2660    35.145524
# col2661    35.145524
# col2662    35.145524
# col2663     0.000000
# Length: 700, dtype: float64

# %%
sns.countplot(x='target', data=df)
plt.title('Распределение целевой переменной')
plt.show()

# %%
object_columns = df.select_dtypes(include=['object']).columns
print(f"\nСтолбцы с типом данных 'object': {object_columns.tolist()}")
# Out:
# Столбцы с типом данных 'object': []

# %%
df.head(30)
# Out:
#     target   col476   col480     col484   col488     col492   col496   col500  \
# 0        0      NaN      NaN        NaN      NaN        NaN      NaN      NaN
# 1        0  59.8983  59.5791  59.738701  59.5791  59.579102  30.2618  30.1154
# 2        0      NaN      NaN        NaN      NaN        NaN      NaN      NaN
# 3        0      NaN      NaN        NaN      NaN        NaN      NaN      NaN
# 4        0      NaN      NaN        NaN      NaN        NaN      NaN      NaN
# 5        0      NaN      NaN        NaN      NaN        NaN      NaN      NaN
# 6        0  55.7386  55.7386  55.738602  55.7386  55.738602  37.6068  37.6068
# 7        0  55.7483  45.0355  47.713699  45.0355  45.035500  38.9750  37.6171
# 8        0      NaN      NaN        NaN      NaN        NaN      NaN      NaN
# 9        0  55.7386  55.7386  55.738602  55.7386  55.738602  37.6068  37.6068
# 10       0      NaN      NaN        NaN      NaN        NaN      NaN      NaN
# 11       0  51.5095  51.5095  51.509499  51.5095  51.509499  -0.0955  -0.0955
# 12       0  59.8983  59.8983  59.898300  59.8983  59.898300  30.2618  30.2618
# 13       0      NaN      NaN        NaN      NaN        NaN      NaN      NaN
# 14       0      NaN      NaN        NaN      NaN        NaN      NaN      NaN
# 15       0      NaN      NaN        NaN      NaN        NaN      NaN      NaN
# 16       0  55.7483  55.6784  55.682767  55.6784  55.678398  37.6171  37.2652
# 17       0      NaN      NaN        NaN      NaN        NaN      NaN      NaN
# 18       0      NaN      NaN        NaN      NaN        NaN      NaN      NaN
# 19       0      NaN      NaN        NaN      NaN        NaN      NaN      NaN
# 20       0      NaN      NaN        NaN      NaN        NaN      NaN      NaN
# 21       0  55.7483  55.7483  55.748299  55.7483  55.748299  37.6171  37.6171
# 22       0  59.8983  59.8983  59.898300  59.8983  59.898300  30.2618  30.2618
# 23       0      NaN      NaN        NaN      NaN        NaN      NaN      NaN
# 24       0      NaN      NaN        NaN      NaN        NaN      NaN      NaN
# 25       0      NaN      NaN        NaN      NaN        NaN      NaN      NaN
# 26       0      NaN      NaN        NaN      NaN        NaN      NaN      NaN
# 27       0  59.8983  59.8983  59.898300  59.8983  59.898300  30.2618  30.2618
# 28       0      NaN      NaN        NaN      NaN        NaN      NaN      NaN
# 29       0  55.7483  55.7483  55.748299  55.7483  55.748299  37.6171  37.6171
#
#        col504   col508  ...      col2651      col2652      col2653  \
# 0         NaN      NaN  ...          NaN          NaN          NaN
# 1   30.188601  30.1154  ...  11789500.00  11789500.00  11789500.00
# 2         NaN      NaN  ...          NaN          NaN          NaN
# 3         NaN      NaN  ...          NaN          NaN          NaN
# 4         NaN      NaN  ...          NaN          NaN          NaN
# 5         NaN      NaN  ...          NaN          NaN          NaN
# 6   37.606800  37.6068  ...   7106000.00   7106000.00   7106000.00
# 7   38.635524  38.9750  ...          NaN          NaN          NaN
# 8         NaN      NaN  ...          NaN          NaN          NaN
# 9   37.606800  37.6068  ...   7014370.00   7014370.00   7014370.00
# 10        NaN      NaN  ...          NaN          NaN          NaN
# 11  -0.095500  -0.0955  ...          NaN          NaN          NaN
# 12  30.261801  30.2618  ...          NaN          NaN          NaN
# 13        NaN      NaN  ...   8976000.00   8976000.00   8976000.00
# 14        NaN      NaN  ...          NaN          NaN          NaN
# 15        NaN      NaN  ...          NaN          NaN          NaN
# 16  37.287195  37.2652  ...   4736654.35   4736654.35   4736654.35
# 17        NaN      NaN  ...          NaN          NaN          NaN
# 18        NaN      NaN  ...          NaN          NaN          NaN
# 19        NaN      NaN  ...          NaN          NaN          NaN
# 20        NaN      NaN  ...          NaN          NaN          NaN
# 21  37.617100  37.6171  ...          NaN          NaN          NaN
# 22  30.261801  30.2618  ...          NaN          NaN          NaN
# 23        NaN      NaN  ...          NaN          NaN          NaN
# 24        NaN      NaN  ...          NaN          NaN          NaN
# 25        NaN      NaN  ...          NaN          NaN          NaN
# 26        NaN      NaN  ...          NaN          NaN          NaN
# 27  30.261801  30.2618  ...          NaN          NaN          NaN
# 28        NaN      NaN  ...          NaN          NaN          NaN
# 29  37.617100  37.6171  ...  12000000.00  12000000.00  12000000.00
#
#         col2654      col2655      col2656      col2660      col2661  \
# 0    4941670.00   4941670.00   4941670.00   4941670.00   4941670.00
# 1   11789500.00  11789500.00  11789500.00  11789500.00  11789500.00
# 2    7000000.00   7000000.00   7000000.00   7000000.00   7000000.00
# 3           NaN          NaN          NaN          NaN          NaN
# 4           NaN          NaN          NaN  10391000.00  10391000.00
# 5           NaN          NaN          NaN   8436000.00   8436000.00
# 6    7106000.00   7106000.00   7106000.00   7106000.00   7106000.00
# 7           NaN          NaN          NaN          NaN          NaN
# 8           NaN          NaN          NaN          NaN          NaN
# 9    7014370.00   7014370.00   7014370.00   7014370.00   7014370.00
# 10   6899000.00   6899000.00   6899000.00   6899000.00   6899000.00
# 11          NaN          NaN          NaN          NaN          NaN
# 12          NaN          NaN          NaN   4400000.00   4400000.00
# 13   8976000.00   8976000.00   8976000.00   8976000.00   8976000.00
# 14          NaN          NaN          NaN          NaN          NaN
# 15          NaN          NaN          NaN  14690000.00  14690000.00
# 16   4736654.35   4736654.35   4736654.35   4736654.35   4736654.35
# 17          NaN          NaN          NaN          NaN          NaN
# 18          NaN          NaN          NaN          NaN          NaN
# 19   6856300.00   6856300.00   6856300.00   6856300.00   6856300.00
# 20          NaN          NaN          NaN   5120000.00   5120000.00
# 21          NaN          NaN          NaN   2500000.00   2500000.00
# 22          NaN          NaN          NaN          NaN          NaN
# 23          NaN          NaN          NaN   1077600.00    953160.00
# 24          NaN          NaN          NaN          NaN          NaN
# 25   3000000.00   3000000.00   3000000.00   3000000.00   3000000.00
# 26          NaN          NaN          NaN          NaN          NaN
# 27          NaN          NaN          NaN   4501000.00   4501000.00
# 28          NaN          NaN          NaN          NaN          NaN
# 29  12000000.00  12000000.00  12000000.00  12000000.00  12000000.00
#
#         col2662   col2663
# 0    4941670.00  0.256919
# 1   11789500.00  0.267221
# 2    7000000.00  0.257217
# 3           NaN  0.256261
# 4   10391000.00  0.257348
# 5    8436000.00  0.256718
# 6    7106000.00  0.266021
# 7           NaN  0.263619
# 8           NaN  0.256261
# 9    7014370.00  0.264464
# 10   6899000.00  0.257017
# 11          NaN  0.316594
# 12   4400000.00  0.256261
# 13   8976000.00  0.257017
# 14          NaN  0.256919
# 15  14690000.00  0.257017
# 16   4736654.35  0.268662
# 17          NaN  0.257217
# 18          NaN  0.256261
# 19   6856300.00  0.258208
# 20   5120000.00  0.256261
# 21   2500000.00  0.262732
# 22          NaN  0.256261
# 23   1015380.00  0.264032
# 24          NaN  0.256261
# 25   3000000.00  0.256919
# 26          NaN  0.256261
# 27   4501000.00  0.260430
# 28          NaN  0.257217
# 29  12000000.00  0.311328
#
# [30 rows x 700 columns]

# %%
df_clean = df.replace(0, np.nan)  # Временно заменяем нули на NaN
df_clean = df_clean.fillna(df_clean.mode().iloc[0])

# %%
df_clean.head()
# Out:
#    target   col476   col480     col484   col488     col492   col496   col500  \
# 0     1.0  59.8983  59.8983  59.898300  59.8983  59.898300  37.6171  30.2618
# 1     1.0  59.8983  59.5791  59.738701  59.5791  59.579102  30.2618  30.1154
# 2     1.0  59.8983  59.8983  59.898300  59.8983  59.898300  37.6171  30.2618
# 3     1.0  59.8983  59.8983  59.898300  59.8983  59.898300  37.6171  30.2618
# 4     1.0  59.8983  59.8983  59.898300  59.8983  59.898300  37.6171  30.2618
#
#       col504   col508  ...     col2651     col2652     col2653     col2654  \
# 0  30.261801  30.2618  ...  12000000.0  12000000.0  12000000.0   4941670.0
# 1  30.188601  30.1154  ...  11789500.0  11789500.0  11789500.0  11789500.0
# 2  30.261801  30.2618  ...  12000000.0  12000000.0  12000000.0   7000000.0
# 3  30.261801  30.2618  ...  12000000.0  12000000.0  12000000.0  12000000.0
# 4  30.261801  30.2618  ...  12000000.0  12000000.0  12000000.0  12000000.0
#
#       col2655     col2656     col2660     col2661     col2662   col2663
# 0   4941670.0   4941670.0   4941670.0   4941670.0   4941670.0  0.256919
# 1  11789500.0  11789500.0  11789500.0  11789500.0  11789500.0  0.267221
# 2   7000000.0   7000000.0   7000000.0   7000000.0   7000000.0  0.257217
# 3  12000000.0  12000000.0   3000000.0   3000000.0   3000000.0  0.256261
# 4  12000000.0  12000000.0  10391000.0  10391000.0  10391000.0  0.257348
#
# [5 rows x 700 columns]

# %%
cols = df_clean.columns
#фиолетовые - пропущенные данные, желтые - не пропущенные
colours = ['#8b00ff', '#ffff00']
sns.heatmap(df_clean[cols].isnull(), cmap=sns.color_palette(colours))
# Out:
# <Axes: >

# %%
df_clean.head()
# Out:
#    target   col476   col480     col484   col488     col492   col496   col500  \
# 0     1.0  59.8983  59.8983  59.898300  59.8983  59.898300  37.6171  30.2618
# 1     1.0  59.8983  59.5791  59.738701  59.5791  59.579102  30.2618  30.1154
# 2     1.0  59.8983  59.8983  59.898300  59.8983  59.898300  37.6171  30.2618
# 3     1.0  59.8983  59.8983  59.898300  59.8983  59.898300  37.6171  30.2618
# 4     1.0  59.8983  59.8983  59.898300  59.8983  59.898300  37.6171  30.2618
#
#       col504   col508  ...     col2651     col2652     col2653     col2654  \
# 0  30.261801  30.2618  ...  12000000.0  12000000.0  12000000.0   4941670.0
# 1  30.188601  30.1154  ...  11789500.0  11789500.0  11789500.0  11789500.0
# 2  30.261801  30.2618  ...  12000000.0  12000000.0  12000000.0   7000000.0
# 3  30.261801  30.2618  ...  12000000.0  12000000.0  12000000.0  12000000.0
# 4  30.261801  30.2618  ...  12000000.0  12000000.0  12000000.0  12000000.0
#
#       col2655     col2656     col2660     col2661     col2662   col2663
# 0   4941670.0   4941670.0   4941670.0   4941670.0   4941670.0  0.256919
# 1  11789500.0  11789500.0  11789500.0  11789500.0  11789500.0  0.267221
# 2   7000000.0   7000000.0   7000000.0   7000000.0   7000000.0  0.257217
# 3  12000000.0  12000000.0   3000000.0   3000000.0   3000000.0  0.256261
# 4  12000000.0  12000000.0  10391000.0  10391000.0  10391000.0  0.257348
#
# [5 rows x 700 columns]

# %%
# Анализ корреляций
correlation_matrix = df_clean.corr()
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, cmap='coolwarm', annot=False)
plt.title('Матрица корреляций признаков')
plt.show()

# %%
df_clean.to_csv('valid_edit3.csv', index=False)
