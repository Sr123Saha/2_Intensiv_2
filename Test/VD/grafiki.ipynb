# %%
import matplotlib.pyplot as plt

dv = 64
ac = 69
pv = 72
ps = 74
main = 78

models = ['baseline 1', 'baseline 2', 'baseline 3', '50/50' 'конечная модель']
accuracies = [dv, ac, pv, ps, main]

plt.figure(figsize=(8, 6))
plt.bar(models, accuracies, color=['orange', 'green', 'blue', 'black', 'red'])

plt.title('Сравнение точности моделей')
plt.xlabel('Модели')
plt.ylabel('Точность (%)')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 13
#      10 accuracies = [dv, ac, pv, ps, main]
#      12 plt.figure(figsize=(8, 6))
# ---> 13 plt.bar(models, accuracies, color=['orange', 'green', 'blue', 'black', 'red'])
#      15 plt.title('Сравнение точности моделей')
#      16 plt.xlabel('Модели')
#
# File ~\AppData\Roaming\Python\Python311\site-packages\matplotlib\pyplot.py:2956, in bar(x, height, width, bottom, align, data, **kwargs)
#    2945 @_copy_docstring_and_deprecators(Axes.bar)
#    2946 def bar(
#    2947     x: float | ArrayLike,
#    (...)
#    2954     **kwargs,
#    2955 ) -> BarContainer:
# -> 2956     return gca().bar(
#    2957         x,
#    2958         height,
#    2959         width=width,
#    2960         bottom=bottom,
#    2961         align=align,
#    2962         **({"data": data} if data is not None else {}),
# ...
