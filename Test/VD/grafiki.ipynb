# %%
import matplotlib.pyplot as plt

dv = 64
ac = 69
pv = 72
ps = 74
ib = 72
main = 78

models = ['baseline 1', 'baseline 2', 'baseline 3', '50/50', 'imblearn', 'Финальная']
accuracies = [dv, ac, pv, ps, ib,  main]

plt.figure(figsize=(8, 6))
plt.bar(models, accuracies, color=['orange', 'green', 'blue', 'purple', 'lime', 'red'])

plt.title('Сравнение точности моделей')
plt.xlabel('Модели')
plt.ylabel('Точность (%)')

plt.show()
